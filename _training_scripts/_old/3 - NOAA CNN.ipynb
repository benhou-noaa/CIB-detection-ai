# %%
#
# model_cnn.py
#
# Train the AlexNet-inspired CNN
#
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.
#

#%% Imports

#from sklearn.model_selection import train_test_split
import csv
import numpy as np
import matplotlib.pyplot as plt

# Keras imports
from keras import optimizers
from keras.models import  Sequential
from keras.layers import Dense, Dropout, Flatten, BatchNormalization
from keras.layers.convolutional import Conv2D, MaxPooling2D
#from sklearn.metrics import roc_curve
#from sklearn.metrics import roc_auc_score
#from sklearn.metrics import precision_recall_curve
#from sklearn.metrics import auc
import os


import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  2

# %%
import cv2

# %%
import PIL

# %%
#tensorflow throws an error related to zlibwapi32
#conda install -c conda-forge zlib-wapi

# %%
"""
Step 1 : Enable Dynamic Memory Allocation

In Jupyter Notebook, restart the kernel (Kernel -> Restart). 
The previous model remains in the memory until the Kernel is restarted, so rerunning the Notebook cells without restarting the kernel may lead to a false Out Of Memory error.

By default, Tensorflow statically allocates the memory in the GPU for the model. 
Larger models can be built when allowing Tensorflow to dynamically allocate the memory.

To enable dynamic memory allocation, run the following commands at the start of the session :
https://www.linkedin.com/pulse/solving-out-memory-oom-errors-keras-tensorflow-running-wayne-cheng
"""

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
#config.gpu_options.per_process_gpu_memory_fraction = 0.7
session = InteractiveSession(config=config)
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#     # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#     try:
#         tf.config.set_logical_device_configuration(
#             gpus[0],
#             [tf.config.LogicalDeviceConfiguration(memory_limit=1024)])
#         logical_gpus = tf.config.list_logical_devices('GPU')
#
#         print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#
#     except RuntimeError as e:
#         # Virtual devices must be set before GPUs have been initialized
#         print(e)

# %%
#%% Path configuration


current_dir = os.path.abspath("Z:\\processing")
data_dir = os.path.join(current_dir, "Data")

model_dir = os.path.join(current_dir,"Model")
spectrogram_dir = os.path.join(data_dir,"Extracted_Spectrogram")
output_spectrogram_vector_dir = os.path.join(data_dir, "Output_Spectrogram_Vector")

for i in [model_dir, output_spectrogram_vector_dir]:

    if not os.path.exists(i):
        os.makedirs(i)

#we need to specify the "training set name" we want to work with
#e.g. BS1KHZ-n721-x1_BDB-n29859-x1
#for replicability's sake, we will store this in a dict

b_positive_variant_dict = {1:"BS1KHZ-n721-x1_BDB-n29859-x1"}
b_false_variant_dict = {1: "FML237-n157-x1_FS1KHZ-n76-x1_FDB-n9860-x1"}
b_negative_variant_dict = {1: "N-n40673-x1"}

# %%
#here you can change which variant you are using
positive_variant = 1
false_variant = 1
negative_variant = 1
model_name = "B{b_var}-F{f_var}-N{n_var}".format(b_var = str(positive_variant), f_var = str(false_variant), n_var = str(negative_variant))
print(model_name)
# Out:
# B1-F1-N1

# %%
#%% Step 1: train/validation/test split

ncol, nrow = 300, 300
spectrogram_suffix = "spectrograms_sample_300_300.npy"
csv_suffix = "filenames_sample.csv"

beluga_positive_basepath = os.path.join(output_spectrogram_vector_dir, "_".join(["beluga-positive", b_positive_variant_dict[positive_variant]]))
beluga_false_basepath = os.path.join(output_spectrogram_vector_dir, "_".join(["beluga-false", b_false_variant_dict[false_variant]]))
beluga_negative_basepath = os.path.join(output_spectrogram_vector_dir, os.path.join("_".join(["beluga-negative", b_negative_variant_dict[negative_variant]])))

#print(beluga_positive_basepath, beluga_false_basepath, beluga_negative_basepath)

#get the numpy arrays
print("loading beluga")
#spectrograms_B_sample = np.load("-".join([beluga_positive_basepath,spectrogram_suffix]))
print("loading false beluga")
spectrograms_F_sample = np.load("-".join([beluga_false_basepath,spectrogram_suffix]))
#print("loading negative beluga")
#spectrograms_N_sample = np.load("-".join([beluga_negative_basepath,spectrogram_suffix]))
# Out:
# loading beluga
# loading false beluga

# %%
test_array = spectrograms_F_sample[0]

# %%
cv2.imshow("x", test_array)
cv2.waitKey()
# Out:
# -1

# %%
pil_image = PIL.Image.open(r"Z:\processing\Data\Extracted_Spectrogram\67158025.190428213002_140_F-ML237.png")
pil_image
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10868\585997143.py in <module>
#       1 pil_image = PIL.Image.open(r"Z:\processing\Data\Extracted_Spectrogram\67158025.190428213002_140_F-ML237.png")
# ----> 2 pil_image[0]
#
# TypeError: 'PngImageFile' object is not subscriptable

# %%
#get the csv files    
filenames_B_sample = []
filenames_F_sample = []
filenames_N_sample = []



#with open("-".join([beluga_positive_basepath, csv_suffix]), newline='') as f:
#    for row in csv.reader(f):
#        filenames_B_sample.append(row[0])

with open("-".join([beluga_false_basepath, csv_suffix]), newline='') as f:
    for row in csv.reader(f):
        filenames_F_sample.append(row[0])

#with open("-".join([beluga_negative_basepath, csv_suffix]), newline='') as f:
#    for row in csv.reader(f):
#        filenames_N_sample.append(row[0])

# %%
filenames_F_sample
# Out:
# ['D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190428213002_140_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190428214502_299_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190428214502_82_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190428220002_212_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190428220002_223_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190428220002_268_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190428220002_269_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190428220002_270_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190428221502_234_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190429114502_140_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190429120002_25_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190429231502_181_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190501023002_109_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190501023002_110_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190501174502_260_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190502133002_110_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190502133002_111_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190502164502_221_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190504023002_97_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190505161502_139_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190505161502_160_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190505163002_15_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190505163002_16_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190513094502_163_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190513113002_157_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190514193002_39_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190515174502_119_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190517134502_27_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190517154502_56_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190517173002_88_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190524001502_20_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190524051502_187_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190525004502_97_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190529104502_6_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190531021502_168_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190603074502_126_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190604053002_139_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190604054502_287_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190604143002_46_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190605033002_163_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190605163002_15_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190606034502_117_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190606134502_106_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190607053002_201_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190608213002_19_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190610084502_118_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190610160002_285_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190610180002_11_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190611034502_106_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190612094502_94_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190612180002_180_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190614043002_223_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190615174502_155_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190616054502_42_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190617073002_256_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190617210002_95_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190619174502_126_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190619193002_105_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190619193002_122_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190621204502_144_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190621204502_264_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190626180002_222_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190628033002_53_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190628034502_60_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190628040002_26_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190629031502_1_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190701154502_2_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190702021502_163_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190703053002_180_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190708074502_78_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190708194502_42_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190709011502_40_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190710134502_194_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190711133002_240_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190712154502_49_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190713054502_97_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190713123002_203_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190713134502_76_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190714011502_44_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190717234502_47_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190718104502_103_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190720124502_18_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190720130002_242_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190720143002_203_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190721034502_176_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190722163002_226_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190725143002_140_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190728010002_48_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190729093002_158_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190729151502_16_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190801033002_117_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190801064502_295_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190801160002_213_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190805190002_1_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190806031502_216_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190807044502_10_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190807113002_161_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190807161502_244_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.190807163002_25_F-ML237.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/67158025.
0_F-DB.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/604536840.171113164502_0_F-DB.png',
#  'D:\\beluga\\Data\\Extracted_Spectrogram/604536840.171113171502_0_F-DB.png',
#  ...]

# %%
spectrograms_B_train_validation, spectrograms_B_test, filenames_B_train_validation, filenames_B_test = train_test_split(spectrograms_B_sample, filenames_B_sample, test_size = 0.3, random_state = 1)
spectrograms_F_train_validation, spectrograms_F_test, filenames_F_train_validation, filenames_F_test = train_test_split(spectrograms_F_sample, filenames_F_sample, test_size = 0.3, random_state = 1)
spectrograms_N_train_validation, spectrograms_N_test, filenames_N_train_validation, filenames_N_test = train_test_split(spectrograms_N_sample, filenames_N_sample, test_size = 0.3, random_state = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b017fe8bbf4d> in <module>
# ----> 1 spectrograms_B_train_validation, spectrograms_B_test, filenames_B_train_validation, filenames_B_test = train_test_split(spectrograms_B_sample, filenames_B_sample, test_size = 0.3, random_state = 1)
#       2 spectrograms_F_train_validation, spectrograms_F_test, filenames_F_train_validation, filenames_F_test = train_test_split(spectrograms_F_sample, filenames_F_sample, test_size = 0.3, random_state = 1)
#       3 spectrograms_N_train_validation, spectrograms_N_test, filenames_N_train_validation, filenames_N_test = train_test_split(spectrograms_N_sample, filenames_N_sample, test_size = 0.3, random_state = 1)
#       4
#
# NameError: name 'train_test_split' is not defined

# %%
spectrograms_train_validation = np.concatenate((spectrograms_B_train_validation, spectrograms_F_train_validation, spectrograms_N_train_validation), axis=0)
labels_train_validation = np.array([1] * len(spectrograms_B_train_validation) + [0] * len(spectrograms_F_train_validation) + [0] * len(spectrograms_N_train_validation))

X_train, X_validation, y_train, y_validation = train_test_split(spectrograms_train_validation, labels_train_validation, test_size = 0.3, random_state = 1)

X_train = X_train / 255.0
X_validation = X_validation / 255.0

print(X_train.shape)   
print(X_validation.shape)   
print(spectrograms_B_test.shape)   
print(spectrograms_F_test.shape)   
print(spectrograms_N_test.shape)
#%% Step 2: build model

def model_cnn(input_shape):
    model = Sequential()

    model.add(Conv2D(128, input_shape=input_shape, kernel_size = (3,3), strides=(2,3), activation='relu', padding='same'))
    model.add(MaxPooling2D(3, strides=(1,2)))
    model.add(BatchNormalization())

    model.add(Conv2D(128, kernel_size = (3,3), strides=(1,1), activation='relu', padding='same'))
    model.add(MaxPooling2D(3, strides=2))
    model.add(BatchNormalization())

    model.add(Conv2D(192, 3, strides=1, activation='relu', padding='same'))
    model.add(Conv2D(192, 3, strides=1, activation='relu', padding='same'))
    model.add(Conv2D(128, 3, strides=1, activation='relu', padding='same'))
    model.add(MaxPooling2D(3, strides=(1,2)))
    model.add(BatchNormalization())

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    return model
model = model_cnn(X_train.shape[1:])
#optimizer = optimizers.SGD(lr=0.001, decay=1e-5, momentum=0.9)

"per https://stackoverflow.com/questions/70568207/attributeerror-module-keras-optimizers-has-no-attribute-adam-i-am-getting"
optimizer = tf.keras.optimizers.Adam(lr=0.0001, decay=1e-7) 
#optimizer = optimizers.adam(lr=0.0001, decay=1e-7)
model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fa2194944bd5> in <module>
# ----> 1 spectrograms_train_validation = np.concatenate((spectrograms_B_train_validation, spectrograms_F_train_validation, spectrograms_N_train_validation), axis=0)
#       2 labels_train_validation = np.array([1] * len(spectrograms_B_train_validation) + [0] * len(spectrograms_F_train_validation) + [0] * len(spectrograms_N_train_validation))
#       3
#       4 X_train, X_validation, y_train, y_validation = train_test_split(spectrograms_train_validation, labels_train_validation, test_size = 0.3, random_state = 1)
#       5
#
# NameError: name 'np' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1f8a688cae5d> in <module>
# ----> 1 model
#
# NameError: name 'model' is not defined

# %%
#es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)  ## early stopping
model_history = model.fit(X_train, y_train, batch_size=2, epochs=15, verbose=1, validation_data=(X_validation, y_validation), max_queue_size=2)
plt.plot(model_history.history['acc'])
plt.plot(model_history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='upper left')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a430ab627db5> in <module>
#       1 #es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)  ## early stopping
# ----> 2 model_history = model.fit(X_train, y_train, batch_size=2, epochs=15, verbose=1, validation_data=(X_validation, y_validation), max_queue_size=2)
#       3 plt.plot(model_history.history['acc'])
#       4 plt.plot(model_history.history['val_acc'])
#       5 plt.title('model accuracy')
#
# NameError: name 'model' is not defined

# %%
os.path.join(model_dir, "-".join([model_name,'cnn_weights_all_data.h5'])

# %%
# Save the weights
model.save_weights(os.path.join(model_dir, "-".join()'cnn_weights_all_data.h5')

# Save the model architecture
with open(os.path.join(model_dir, 'cnn_architecture_all_data.json'), 'w') as f:
    f.write(model.to_json())


#%% Step 3: predict on the test set
    
del X_train
del X_validation
del spectrograms_B_train_validation
del spectrograms_F_train_validation
del spectrograms_N_train_validation

spectrograms_B_test_predict = model.predict(spectrograms_B_test / 255.0)
spectrograms_B_test_wrong_predictions = [i for i,v in enumerate(spectrograms_B_test_predict) if v < 0.5]
plt.hist(spectrograms_B_test_predict)
print(1 - len(spectrograms_B_test_wrong_predictions) / len(spectrograms_B_test_predict))

spectrograms_F_test_predict = model.predict(spectrograms_F_test / 255.0)
spectrograms_F_test_wrong_predictions = [i for i,v in enumerate(spectrograms_F_test_predict) if v > 0.5]
plt.hist(spectrograms_F_test_predict)
print(1 - len(spectrograms_F_test_wrong_predictions) / len(spectrograms_F_test_predict))

spectrograms_N_test_predict = model.predict(spectrograms_N_test / 255.0)
spectrograms_N_test_wrong_predictions = [i for i,v in enumerate(spectrograms_N_test_predict) if v > 0.5]
plt.hist(spectrograms_N_test_predict)
print(1 - len(spectrograms_N_test_wrong_predictions) / len(spectrograms_N_test_predict))

tp = len([i for i,v in enumerate(spectrograms_B_test_predict) if v >= 0.5])
fn = len([i for i,v in enumerate(spectrograms_B_test_predict) if v < 0.5])
tn = len([i for i,v in enumerate(spectrograms_F_test_predict) if v < 0.5])
fp = len([i for i,v in enumerate(spectrograms_F_test_predict) if v >= 0.5])
precision = tp / (tp + fp) 
recall = tp / (tp + fn)
accuracy = (tp + tn) / (tp + fp + tn + fn)

y_true = [1] * len(spectrograms_B_test_predict) + [0] * len(spectrograms_F_test_predict)
y_scores = spectrograms_B_test_predict.tolist() + spectrograms_F_test_predict.tolist()

# Calculate ROC and AUC
AUC = roc_auc_score(y_true, y_scores) 
print('AUC: %.4f' % AUC)

# Calculate ROC Curve
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
plt.plot(fpr, tpr, marker='.')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# Calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
precision_recall_auc = auc(recall, precision)
print('Precesion Recall AUC: %.4f' % precision_recall_auc)

# Plot precision-recall curve
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.show()
